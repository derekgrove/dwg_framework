# %%
import cloudpickle

TChiWZ_18_pikl = "pikls/20251219_142853/SMS-TChiWZZToLLmZMin-0p1TuneCP513TeV-madgraphMLM-pythia8RunIISummer20UL18NanoAODv9-106Xupgrade2018realisticv16L1v1-v1NANOAODSIM.pkl"
#TChiWZ_17_pikl = "pikls/20251219_142853/TChiWZ2017UL.pkl"

with open(TChiWZ_18_pikl, "rb") as f:
    TChiWZ_18 = cloudpickle.load(f)

#with open(TChiWZ_17_pikl, "rb") as f:
#    TChiWZ_17 = cloudpickle.load(f)

# %%
TChiWZ_17
# Out:
# {'result': {'ele_hist': Hist(
#     Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Electron $p_T$ (GeV)'),
#     Regular(500, 0, 500, name='pt_long', label='Electron $p_T$ (GeV)'),
#     Variable([0, 0.8, 1.4442, 1.556, 2.5], name='eta', label='Electron $\\eta$'),
#     IntCategory([-10, 1, 10, 100, 1000], name='gen', label='Electron Gen Tag'),
#     IntCategory([-1, 1, 10, 100], name='qual', label='Electron Quality Tag'),
#     storage=Double()) # Sum: 12677283.0 (14267715.0 with flow),
#   'muon_hist': Hist(
#     Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Muon $p_T$ (GeV)'),
#     Regular(500, 0, 500, name='pt_long', label='Muon $p_T$ (GeV)'),
#     Variable([0, 0.9, 1.2, 2.1, 2.4], name='eta', label='Muon $\\eta$'),
#     IntCategory([-10, 1, 10, 100, 1000], name='gen', label='Muon Gen Tag'),
#     IntCategory([-1, 1, 10, 100], name='qual', label='Muon Quality Tag'),
#     storage=Double())},
#  'metrics': {'bytesread': 2214667221,
# ...

# %%
TChiWZ_18['result']
# Out:
# {'ele_hist': Hist(
#    Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Electron $p_T$ (GeV)'),
#    Regular(500, 0, 500, name='pt_long', label='Electron $p_T$ (GeV)'),
#    Variable([0, 0.8, 1.4442, 1.556, 2.5], name='eta', label='Electron $\\eta$'),
#    IntCategory([-10, 1, 10, 100, 1000], name='gen', label='Electron Gen Tag'),
#    IntCategory([-1, 1, 10, 100], name='qual', label='Electron Quality Tag'),
#    storage=Double()) # Sum: 13983575.0 (15626078.0 with flow),
#  'muon_hist': Hist(
#    Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Muon $p_T$ (GeV)'),
#    Regular(500, 0, 500, name='pt_long', label='Muon $p_T$ (GeV)'),
#    Variable([0, 0.9, 1.2, 2.1, 2.4], name='eta', label='Muon $\\eta$'),
#    IntCategory([-10, 1, 10, 100, 1000], name='gen', label='Muon Gen Tag'),
#    IntCategory([-1, 1, 10, 100], name='qual', label='Muon Quality Tag'),
#    storage=Double())}

# %%
from plotting.pt_eta_eff import plot_eta_pt_eff

# %%
import matplotlib.pyplot as plt

# %%
plot_eta_pt_eff(
    TChiWZ_18['result']['ele_hist'].integrate("pt_long")[:,:,1j, 100j], 
    TChiWZ_18['result']['ele_hist'].integrate("pt_long").integrate("qual", [1j,10j,100j])[:,:, 1j],
    "",
    sample_name=f"SMS-TChiWZ-ZToLLmZMin-2018-UL",
    save_name="ele_TChiWZ_2018",
    color='plasma',
    vmin=0,
    vmax=1,
    event_count=None,
    com=13
)
# Out:
# (Hist(
#   Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Electron $p_T$ (GeV)'),
#   Variable([0, 0.8, 1.4442, 1.556, 2.5], name='eta', label='Electron $\\eta$'),
#   storage=Double()) # Sum: nan (nan with flow), array([[0.00129417, 0.00222961,        nan,        nan],
#        [0.00128224, 0.00206716,        nan,        nan],
#        [0.00144213, 0.00214089,        nan,        nan],
#        [0.00104403, 0.00161676,        nan,        nan],
#        [0.00169837, 0.00208895,        nan,        nan],
#        [0.00083069, 0.00112389, 0.00383713, 0.00135313],
#        [0.0005909 , 0.0007938 , 0.00298934, 0.00108813],
#        [0.00118952, 0.00167449, 0.00695562, 0.0026076 ],
#        [0.00235313, 0.00359994, 0.01644739, 0.00651785]]))
# [   2.    3.    4.    5.    7.   10.   20.   45.   75. 1000.]
# ['2 - 3', '3 - 4', '4 - 5', '5 - 7', '7 - 10', '10 - 20', '20 - 45', '45 - 75', '75 - 1000']
# range(0, 10)
# [0.     0.8    1.4442 1.556  2.5   ]
# ...

# %%
plot_eta_pt_eff(
    TChiWZ_18['result']['muon_hist'].integrate("pt_long")[:,:,1j, 100j], 
    TChiWZ_18['result']['muon_hist'].integrate("pt_long").integrate("qual", [1j,10j,100j])[:,:, 1j],
    "",
    sample_name=f"SMS-TChiWZ-ZToLLmZMin-2018-UL",
    save_name="muon_TChiWZ_2018",
    color='plasma',
    vmin=0,
    vmax=1,
    event_count=None,
    muon_hist=True,
    com=13
)
# Out:
# (Hist(
#   Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Muon $p_T$ (GeV)'),
#   Variable([0, 0.9, 1.2, 2.1, 2.4], name='eta', label='Muon $\\eta$'),
#   storage=Double()) # Sum: nan (nan with flow), array([[       nan,        nan,        nan,        nan],
#        [0.00145154, 0.00243356,        nan,        nan],
#        [0.001156  , 0.00215637,        nan,        nan],
#        [0.00074386, 0.00150734, 0.00141952, 0.00377791],
#        [0.00066401, 0.0013107 , 0.00090273, 0.00235291],
#        [0.00046475, 0.00094007, 0.00065298, 0.00168883],
#        [0.00052821, 0.00104493, 0.00074468, 0.00206673],
#        [0.00119777, 0.00241541, 0.00182384, 0.00558717],
#        [0.00256372, 0.005261  , 0.00427886, 0.01613528]]))
# [   2.    3.    4.    5.    7.   10.   20.   45.   75. 1000.]
# ['2 - 3', '3 - 4', '4 - 5', '5 - 7', '7 - 10', '10 - 20', '20 - 45', '45 - 75', '75 - 1000']
# range(0, 10)
# [0.  0.9 1.2 2.1 2.4]
# ...

# %%
plot_eta_pt_eff(
    TChiWZ_17['result']['ele_hist'].integrate("pt_long")[:,:,1j, 100j], 
    TChiWZ_17['result']['ele_hist'].integrate("pt_long").integrate("qual", [1j,10j,100j])[:,:, 1j],
    "",
    sample_name=f"SMS-TChiWZ-ZToLLmZMin-2017-UL",
    save_name="ele_TChiWZ_2017",
    color='plasma',
    vmin=0,
    vmax=1,
    event_count=None,
    com=13
)
# Out:
# (Hist(
#   Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Electron $p_T$ (GeV)'),
#   Variable([0, 0.8, 1.4442, 1.556, 2.5], name='eta', label='Electron $\\eta$'),
#   storage=Double()) # Sum: nan (nan with flow), array([[0.00133681, 0.00234176,        nan,        nan],
#        [0.00111358, 0.00160755,        nan,        nan],
#        [0.00097528, 0.0015362 ,        nan,        nan],
#        [0.00066708, 0.00105528, 0.00412043, 0.00192965],
#        [0.0007595 , 0.0010183 , 0.00263444, 0.00124306],
#        [0.00046948, 0.00065664, 0.00197897, 0.00083888],
#        [0.00043342, 0.00059088, 0.00183211, 0.00080506],
#        [0.00094958, 0.00132398, 0.00446651, 0.00203898],
#        [0.00192513, 0.00290729, 0.01021204, 0.00502063]]))
# [   2.    3.    4.    5.    7.   10.   20.   45.   75. 1000.]
# ['2 - 3', '3 - 4', '4 - 5', '5 - 7', '7 - 10', '10 - 20', '20 - 45', '45 - 75', '75 - 1000']
# range(0, 10)
# [0.     0.8    1.4442 1.556  2.5   ]
# ...

# %%
plot_eta_pt_eff(
    TChiWZ_17['result']['ele_hist'].integrate("pt_long")[:,:,1j, 100j], 
    TChiWZ_17['result']['ele_hist'].integrate("pt_long").integrate("qual", [1j,10j,100j])[:,:, 1j],
    "",
    sample_name=f"SMS-TChiWZ-ZToLLmZMin-2017-UL",
    save_name="ele_TChiWZ_2017",
    color='plasma',
    vmin=0,
    vmax=1,
    event_count=None,
    com=13
)
# Out:
# (Hist(
#   Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Electron $p_T$ (GeV)'),
#   Variable([0, 0.8, 1.4442, 1.556, 2.5], name='eta', label='Electron $\\eta$'),
#   storage=Double()) # Sum: nan (nan with flow), array([[0.00133681, 0.00234176,        nan,        nan],
#        [0.00111358, 0.00160755,        nan,        nan],
#        [0.00097528, 0.0015362 ,        nan,        nan],
#        [0.00066708, 0.00105528, 0.00412043, 0.00192965],
#        [0.0007595 , 0.0010183 , 0.00263444, 0.00124306],
#        [0.00046948, 0.00065664, 0.00197897, 0.00083888],
#        [0.00043342, 0.00059088, 0.00183211, 0.00080506],
#        [0.00094958, 0.00132398, 0.00446651, 0.00203898],
#        [0.00192513, 0.00290729, 0.01021204, 0.00502063]]))
# [   2.    3.    4.    5.    7.   10.   20.   45.   75. 1000.]
# ['2 - 3', '3 - 4', '4 - 5', '5 - 7', '7 - 10', '10 - 20', '20 - 45', '45 - 75', '75 - 1000']
# range(0, 10)
# [0.     0.8    1.4442 1.556  2.5   ]
# ...
