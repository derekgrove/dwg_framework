# %%
import cloudpickle

results_pikl = "pikls/20260205_143233/all_datasets_full.pkl"

#TChiWZ_17_pikl = "pikls/20251219_142853/TChiWZ2017UL.pkl"

with open(results_pikl, "rb") as f:
    json = cloudpickle.load(f)
    results = json["results"]

# %%
results.keys()
# Out:
# dict_keys(['SlepSnu2202602402023', 'TChiWZ2017UL', 'TTto2L2Nu2017UL', 'TTto2L2Nu2023'])

# %%
results[list(results.keys())[0]].keys()
# Out:
# dict_keys(['tau_hist', 'gen_tau_hist'])

# %%
results[list(results.keys())[0]]["tau_hist"]
# Out:
# Hist(
#   Variable([2, 3, 4, 5, 7, 10, 20, 45, 75, 1000], name='pt', label='Tau $p_T$ (GeV)'),
#   Regular(500, 0, 500, name='pt_long', label='Tau $p_T$ (GeV)'),
#   Regular(50, 0, 2.5, name='eta_long', label='Tau $\\eta$'),
#   Variable([0, 0.8, 1.4442, 1.556, 2.5], name='eta', label='Tau $\\eta$'),
#   IntCategory([-1, 1, 10, 100, 1000, 10000, 100000], name='gen', label='Tau Gen Tag'),
#   storage=Double())

# %%
import matplotlib.pyplot as plt
import mplhep

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import mplhep

fig, axs = plt.subplots(2, 2, figsize=(20, 20))
mplhep.style.use(mplhep.style.CMS)

# (optional) avoid log(0) problems
vmin = 1

results["SlepSnu2202602402023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10j]) \
    [:100, :].plot(ax=axs[0, 0])

axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)


results["TChiWZ2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10j]) \
    [:100, :].plot(ax=axs[0, 1])

axs[0, 1].set_title("TChiWZ2017UL", fontsize=28)


results["TTto2L2Nu2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10j]) \
    [:100, :].plot(ax=axs[1, 0])

axs[1, 0].set_title("TTto2L2Nu2017UL", fontsize=28)


results["TTto2L2Nu2023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10j]) \
    [:100, :].plot(ax=axs[1, 1])

axs[1, 1].set_title("TTto2L2Nu2023", fontsize=28)

fig.suptitle("Electron Faking Tau")
plt.tight_layout()
plt.savefig("ele_fake_tau")
plt.show()

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import mplhep

fig, axs = plt.subplots(2, 2, figsize=(20, 20))
mplhep.style.use(mplhep.style.CMS)

# (optional) avoid log(0) problems
vmin = 1

results["SlepSnu2202602402023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100j]) \
    [:100, :].plot(ax=axs[0, 0])

axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)


results["TChiWZ2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100j]) \
    [:100, :].plot(ax=axs[0, 1])

axs[0, 1].set_title("TChiWZ2017UL", fontsize=28)


results["TTto2L2Nu2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100j]) \
    [:100, :].plot(ax=axs[1, 0])

axs[1, 0].set_title("TTto2L2Nu2017UL", fontsize=28)


results["TTto2L2Nu2023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100j]) \
    [:100, :].plot(ax=axs[1, 1])

axs[1, 1].set_title("TTto2L2Nu2023", fontsize=28)

fig.suptitle("Muon Faking Tau")
plt.tight_layout()
plt.savefig("mu_fake_tau")
plt.show()

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import mplhep

fig, axs = plt.subplots(2, 2, figsize=(20, 20))
mplhep.style.use(mplhep.style.CMS)

# (optional) avoid log(0) problems
vmin = 1

results["SlepSnu2202602402023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1000j]) \
    [:100, :].plot(ax=axs[0, 0])

axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)


results["TChiWZ2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1000j]) \
    [:100, :].plot(ax=axs[0, 1])

axs[0, 1].set_title("TChiWZ2017UL", fontsize=28)


results["TTto2L2Nu2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1000j]) \
    [:100, :].plot(ax=axs[1, 0])

axs[1, 0].set_title("TTto2L2Nu2017UL", fontsize=28)


results["TTto2L2Nu2023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1000j]) \
    [:100, :].plot(ax=axs[1, 1])

axs[1, 1].set_title("TTto2L2Nu2023", fontsize=28)

fig.suptitle("Tau -> Electron")
plt.tight_layout()
plt.savefig("tau_ele")
plt.show()

# %%
results["TTto2L2Nu2017UL"]["tau_hist"].integrate("pt").integrate("eta").integrate("gen", [10j])[:100, :].plot()
# Out:
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7fdf1a640bc0>, cbar=<matplotlib.colorbar.Colorbar object at 0x7fdf1a5f7a70>, text=[])

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import mplhep

fig, axs = plt.subplots(2, 2, figsize=(20, 20))
mplhep.style.use(mplhep.style.CMS)

# (optional) avoid log(0) problems
vmin = 1

results["SlepSnu2202602402023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10000j]) \
    [:100, :].plot(ax=axs[0, 0])

axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)


results["TChiWZ2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10000j]) \
    [:100, :].plot(ax=axs[0, 1])

axs[0, 1].set_title("TChiWZ2017UL", fontsize=28)


results["TTto2L2Nu2017UL"]["tau_hist"].integrate("pt").integrate("eta").integrate("gen", [10000j])[:100, :].plot(ax=axs[1, 0])

axs[1, 0].set_title("TTto2L2Nu2017UL", fontsize=28)


results["TTto2L2Nu2023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [10000j]) \
    [:100, :].plot(ax=axs[1, 1])

axs[1, 1].set_title("TTto2L2Nu2023", fontsize=28)

fig.suptitle("Tau -> Muon")
plt.tight_layout()
plt.savefig("tau_mu")
plt.show()

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import mplhep

fig, axs = plt.subplots(2, 2, figsize=(20, 20))
mplhep.style.use(mplhep.style.CMS)

# (optional) avoid log(0) problems
vmin = 1

results["SlepSnu2202602402023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100000j]) \
    [:100, :].plot(ax=axs[0, 0], norm=colors.LogNorm(vmin=vmin))

axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)


results["TChiWZ2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100000j]) \
    [:100, :].plot(ax=axs[0, 1], norm=colors.LogNorm(vmin=vmin))

axs[0, 1].set_title("TChiWZ2017UL", fontsize=28)


results["TTto2L2Nu2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100000j]) \
    [:100, :].plot(ax=axs[1, 0], norm=colors.LogNorm(vmin=vmin))

axs[1, 0].set_title("TTto2L2Nu2017UL", fontsize=28)


results["TTto2L2Nu2023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [100000j]) \
    [:100, :].plot(ax=axs[1, 1], norm=colors.LogNorm(vmin=vmin))

axs[1, 1].set_title("TTto2L2Nu2023", fontsize=28)

fig.suptitle("Tau -> Hadronic")
plt.tight_layout()
plt.savefig("tau_hadron")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 15
#       8 # (optional) avoid log(0) problems
#       9 vmin = 1
#      11 results["SlepSnu2202602402023"]["tau_hist"] \
#      12     .integrate("pt") \
#      13     .integrate("eta") \
#      14     .integrate("gen", [100000j]) \
# ---> 15     [:100, :].plot(ax=axs[0, 0], norm=colors.LogNorm(vmin=vmin))
#      17 axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)
#      20 results["TChiWZ2017UL"]["tau_hist"] \
#      21     .integrate("pt") \
#      22     .integrate("eta") \
#      23     .integrate("gen", [100000j]) \
#      24     [:100, :].plot(ax=axs[0, 1], norm=colors.LogNorm(vmin=vmin))
#
# File /usr/local/lib/python3.12/site-packages/hist/basehist.py:556, in BaseHist.plot(self, overlay, *args, **kwargs)
#     553     return self.plot1d(*args, overlay=overlay, **kwargs)
# ...

# %%
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import mplhep

fig, axs = plt.subplots(2, 2, figsize=(20, 20))
mplhep.style.use(mplhep.style.CMS)

# (optional) avoid log(0) problems
vmin = 1

results["SlepSnu2202602402023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1j]) \
    [:100, :].plot(ax=axs[0, 0])

axs[0, 0].set_title("SlepSnu220_260_240_2023", fontsize=28)


results["TChiWZ2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1j]) \
    [:100, :].plot(ax=axs[0, 1])

axs[0, 1].set_title("TChiWZ2017UL", fontsize=28)


results["TTto2L2Nu2017UL"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1j]) \
    [:100, :].plot(ax=axs[1, 0])

axs[1, 0].set_title("TTto2L2Nu2017UL", fontsize=28)


results["TTto2L2Nu2023"]["tau_hist"] \
    .integrate("pt") \
    .integrate("eta") \
    .integrate("gen", [1j]) \
    [:100, :].plot(ax=axs[1, 1])

axs[1, 1].set_title("TTto2L2Nu2023", fontsize=28)

fig.suptitle("Unmatched Tau")
plt.tight_layout()
plt.savefig("unmatched_tau")
plt.show()
