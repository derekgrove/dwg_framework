# %%
import coffea, hist
print(coffea.__version__)
print(hist.__version__)
# Out:
# 2025.10.2
# 2.9.0

# %%
import awkward as ak
import hist

#import boost_histogram as bh

#import dask.array as da

#import dask_histogram as dh

import json
import sys

from coffea import processor
from coffea.nanoevents import NanoAODSchema, BaseSchema


from taggers.lep_tagger_dev import tag_qual, tag_qual_and_gen

class Processor(processor.ProcessorABC):
    def __init__(self, mode="virtual"):
        assert mode in ["virtual", "eager", "dask"]
        self._mode = mode

    def process(self, events):
        dataset = events.metadata["dataset"]
        print(dataset)

        is_UL = events.metadata.get("is_UL", False)

        events = tag_qual(events)

        events_2 = tag_qual_and_gen(events)

        leps_wo_gen = events.Leptons

        leps_w_gen = events_2.Leptons

        h_pt = hist.Hist(
            hist.axis.Regular(50, 0, 200, name="gen", label="gen"),
        )
        
        # Fill histogram
        h_pt.fill(
            gen=ak.flatten(leps_w_gen.gen_tag)
           )
        
        output = {
            "lep_wo_gen_fields": leps_wo_gen.fields,
            "lep_w_gen_fields": leps_w_gen.fields,
            "h_pt": h_pt
        } 


        #Do analysis here, fill output dict with results
                
        return output  
        
    def postprocess(self, accumulator):
        pass

# %%
import cloudpickle
import os
from datetime import datetime
from dask.distributed import Client

# Create pickles directory if it doesn't exist
os.makedirs("pikls", exist_ok=True)

# Set mode
mode = "virtual"  # or "dask"
make_pikl = False

#fileset_name = "fileset_full.txt"
fileset_name = "fileset.txt"


results = {}
all_metrics = {}

with open(fileset_name, "r") as f:
    exec(f.read())

# Set up executor based on mode
if mode == "dask":
    client = Client("tls://localhost:8786")
    executor = processor.DaskExecutor(client=client)
    
else:  # virtual mode
    executor = processor.IterativeExecutor()

# Set up output directory
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
output_dir = f"pikls/{timestamp}"
os.makedirs(output_dir, exist_ok=True)

# Process each dataset
for dataset_name in fileset.keys():
    print(f"\nProcessing {dataset_name}...")
    
    single_fileset = {dataset_name: fileset[dataset_name]}
    
    runner = processor.Runner(
        executor=executor,
        schema=NanoAODSchema,
        savemetrics=True,
        skipbadfiles=False,
    )
    
    result, metrics = runner(single_fileset, processor_instance=Processor(mode=mode))
    results[dataset_name] = result
    all_metrics[dataset_name] = metrics
    
    if make_pikl:
        output_file = f"{output_dir}/{dataset_name}.pkl"
        
        with open(output_file, "wb") as f:
            cloudpickle.dump({'result': result, 'metrics': metrics}, f)
        
        print(f"Saved {output_file}")

# Save combined results
if make_pikl:
    output_file = f"{output_dir}/all_datasets_full.pkl"
    
    with open(output_file, "wb") as f:
        cloudpickle.dump({'results': results, 'metrics': all_metrics}, f)
    
    print(f"Saved {output_file}")
# Out:
# Output()
# Processing WtoLNu-2JetsTuneCP513p6TeVamcatnloFXFX-pythia8...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# WtoLNu-2JetsTuneCP513p6TeVamcatnloFXFX-pythia8
# WtoLNu-2JetsTuneCP513p6TeVamcatnloFXFX-pythia8
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Processing SMS-TChiWZZToLLmZMin-0p1TuneCP513TeV-madgraphMLM-pythia8RunIISummer20UL18NanoAODv9-106Xupgrade2018realisticv16L1v1-v1NANOAODSIM...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# /usr/local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing
# cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /usr/local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing
# cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# SMS-TChiWZZToLLmZMin-0p1TuneCP513TeV-madgraphMLM-pythia8RunIISummer20UL18NanoAODv9-106Xupgrade2018realisticv16L1v1-
# v1NANOAODSIM
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:1493, in Runner._work_function(format, xrootdtimeout, schema, use_dataframes, savemetrics, item, processor_instance, uproot_options, iteritems_options, checkpointer)
#    1492 if isinstance(processor_instance, ProcessorABC):
# -> 1493     out = processor_instance.process(events)
#    1494 else:
#
# Cell In[2], line 30, in Processor.process(self, events)
#      28 is_UL = events.metadata.get("is_UL", False)
# ---> 30 events = tag_qual(events)
#      32 events_2 = tag_qual_and_gen(events)
#
# File ~/dwg_framework/src/taggers/lep_tagger_dev.py:19, in tag_qual(events)
#      18 # Tag lepton collections
# ---> 19 tagged_electrons = tag_ele_quality(events.Electron)
#      20 tagged_low_pt_electrons = tag_lpte_quality(events.LowPtElectron)
#
# File ~/dwg_framework/src/taggers/lep_tagger_dev.py:127, in tag_ele_quality(ele)
#     118 low_pt_pass = (
#     119     (pt < 20)
#     120     & (iso03pt <= 4)
#     121     & (miniIsoPt <= 4)
#     122     & tight_minus_iso_hoe(ele)
#     123 )
#     125 high_pt_pass = (
#     126     (pt >= 20)
# --> 127     & ele.mvaIso_WP90
#     128 )
#     131 gold_silver_mask = baseline_mask & (low_pt_pass | high_pt_pass)
#
# File /usr/local/lib/python3.12/site-packages/awkward/highlevel.py:1298, in Array.__getattr__(self, where)
#    1297 else:
# -> 1298     raise AttributeError(f"no field named {where!r}")
#
# AttributeError: no field named 'mvaIso_WP90'
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 49
#      40 single_fileset = {dataset_name: fileset[dataset_name]}
#      42 runner = processor.Runner(
#      43     executor=executor,
#      44     schema=NanoAODSchema,
#      45     savemetrics=True,
#      46     skipbadfiles=False,
#      47 )
# ---> 49 result, metrics = runner(single_fileset, processor_instance=Processor(mode=mode))
#      50 results[dataset_name] = result
#      51 all_metrics[dataset_name] = metrics
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:1565, in Runner.__call__(self, fileset, processor_instance, treename, uproot_options, iteritems_options, *args)
#    1562     if len(args) > 2:
#    1563         iteritems_options = args[2]
# -> 1565 wrapped_out = self.run(
#    1566     fileset=fileset,
#    1567     processor_instance=processor_instance,
#    1568     treename=treename,
#    1569     uproot_options=uproot_options,
#    1570     iteritems_options=iteritems_options,
#    1571 )
#    1572 if self.use_dataframes:
#    1573     return wrapped_out  # not wrapped anymore
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:1731, in Runner.run(self, fileset, processor_instance, treename, uproot_options, iteritems_options, *args)
#    1726 closure = partial(
#    1727     self.automatic_retries, self.retries, self.skipbadfiles, closure
#    1728 )
#    1730 executor = self.executor.copy(**exe_args)
# -> 1731 wrapped_out, e = executor(chunks, closure, None)
#    1732 if wrapped_out is None:
#    1733     raise ValueError(
#    1734         "No chunks returned results, verify ``processor`` instance structure.\n\
#    1735         if you used skipbadfiles=True, it is possible all your files are bad."
#    1736     )
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:492, in IterativeExecutor.__call__(self, items, function, accumulator)
#     487 with rich_bar() as progress:
#     488     p_id = progress.add_task(
#     489         self.desc, total=len(items), unit=self.unit, disable=not self.status
#     490     )
#     491     return (
# --> 492         accumulate(
#     493             progress.track(
#     494                 map(function, (c for c in items)),
#     495                 total=len(items),
#     496                 task_id=p_id,
#     497             ),
#     498             accumulator,
#     499         ),
#     500         0,
#     501     )
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/accumulator.py:96, in accumulate(items, accum)
#      94 try:
#      95     if accum is None:
# ---> 96         accum = next(gen)
#      97         # we want to produce a new object so that the input is not mutated
#      98         accum = add(accum, next(gen))
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/accumulator.py:93, in <genexpr>(.0)
#      90 def accumulate(
#      91     items: Iterable[Optional[Accumulatable]], accum: Optional[Accumulatable] = None
#      92 ) -> Optional[Accumulatable]:
# ---> 93     gen = (x for x in items if x is not None)
#      94     try:
#      95         if accum is None:
#
# File /usr/local/lib/python3.12/site-packages/rich/progress.py:1231, in Progress.track(self, sequence, total, completed, task_id, description, update_period)
#    1229 advance = self.advance
#    1230 refresh = self.refresh
# -> 1231 for value in sequence:
#    1232     yield value
#    1233     advance(task_id, 1)
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:1150, in Runner.automatic_retries(retries, skipbadfiles, func, *args, **kwargs)
#    1144         break
#    1145     if (
#    1146         not skipbadfiles
#    1147         or any("Auth failed" in str(c) for c in chain)
#    1148         or retries == retry_count
#    1149     ):
# -> 1150         raise e
#    1151     warnings.warn("Attempt %d of %d." % (retry_count + 1, retries + 1))
#    1152 retry_count += 1
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:1120, in Runner.automatic_retries(retries, skipbadfiles, func, *args, **kwargs)
#    1118 while retry_count <= retries:
#    1119     try:
# -> 1120         return func(*args, **kwargs)
#    1121     # catch xrootd errors and optionally skip
#    1122     # or retry to read the file
#    1123     except Exception as e:
#
# File /usr/local/lib/python3.12/site-packages/coffea/processor/executor.py:1497, in Runner._work_function(format, xrootdtimeout, schema, use_dataframes, savemetrics, item, processor_instance, uproot_options, iteritems_options, checkpointer)
#    1495         out = processor_instance(events)
#    1496 except Exception as e:
# -> 1497     raise Exception(
#    1498         f"Failed processing file: {item!r}. The error was: {e!r}."
#    1499     ) from e
#    1500 if out is None:
#    1501     raise ValueError(
#    1502         "Output of process() should not be None. Make sure your processor's process() function returns an accumulator."
#    1503     )
#
# Exception: Failed processing file: WorkItem(dataset='SMS-TChiWZZToLLmZMin-0p1TuneCP513TeV-madgraphMLM-pythia8RunIISummer20UL18NanoAODv9-106Xupgrade2018realisticv16L1v1-v1NANOAODSIM', filename='root://cms-xrd-global.cern.ch//store/mc/RunIISummer20UL18NanoAODv9/SMS-TChiWZ_ZToLL_mZMin-0p1_TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/106X_upgrade2018_realistic_v16_L1v1-v1/2560000/09873976-BDB9-AD4E-8D15-3CB28937D990.root', treename='Events', entrystart=0, entrystop=98050, fileuuid=b'\xf3\xa9\xd6\xea\xa3\x0e\x11\xed\xa3HD\xbf\xe1\x83\xbe\xef', usermeta={'is_mc': True, 'is_UL': True}). The error was: AttributeError("no field named 'mvaIso_WP90'").

# %%
result['h_pt'].values
# Out:
# <bound method Histogram.values of Hist(Regular(50, 0, 200, name='gen'), storage=Double()) # Sum: 310970.0 (339328.0 with flow)>

# %%
result['lep_w_gen_fields']

# %%
result['ele_pt']

# %%
result['lpte_pt']

# %%
result['muon_pt']

# %%
result['ele_fields']

# %%
list(result.keys())

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
fig, axs = plt.subplots(figsize=(11, 5))
result['MET_lt_150_dilep_ss_mumu_plot'].integrate("qual_sum", [2j, 20j, 200j, 11j, 110j, 101j]).plot2d(norm=LogNorm())
#result['MET_lt_150_dilep_ss_mumu_plot'].integrate("qual_sum").plot2d(norm=LogNorm())

# %%
result['MET_lt_150_dilep_ss_mumu_plot_ratio'].plot()
plt.yscale('log')

# %%
def baseline(hist):
    return hist.integrate("qual_sum", [2j,11j,20j,101j,110j,200j])
baseline(result['MET_lt_150_dilep_ss_mumu_plot']).plot2d(norm=LogNorm())

# %%
h = result['MET_lt_150_dilep_ss_mumu_plot_ratio']
fig, axs = plt.subplots(figsize=(11, 5))
# Create a label mapping for the qual_sum axis
labels = [
    "ff",
    "fb",
    "bb",
    "fs",
    "bs",
    "ss",
    "fg",
    "gb",
    "gs",
    "gg"
]

#plt.gca().set_yticklabels(labels)
#h.axes['dr_div_m'].label = r"$\frac{\Delta R}{m_{\ell\ell}}$"
h.plot2d(norm=LogNorm())
# Now plot

# %%
u_qs

# %%
h.integrate("qual_sum", 101j)[:,:]

# %%
result

# %%
result['300_290']['300_290_dilep_plot'].integrate("qual_sum", 20j)

# %%
print(result['MET_lt_150_dilep_os_mumu_plot'].sum(flow=True))
print(result['MET_lt_150_dilep_os_mumu_count'])

# %%
result.keys()

# %%
results.keys()

# %%
result.keys()

# %%
for key in results[list(results)[0]].keys():
    print(key)

# %%
results[list(results)[0]]["MET_lt_150_dilep_os_ee_plot"]

# %%
#results[sig_name]['lpte_dict']['pt_ID_hist'].integrate("qual_tag")[:,:, 10j]
#r['test_dict']['pt_eta_hist'].project('pt', 'qual_tag').plot()
#TChi_r['electron_dict']['pt_gen_qual_hist'][:,10j,3j]

#[-2, 0, 1, 2, 3, 4, 5, 6]

# %%
results[list(results)[0]]["MET_lt_150_dilep_os_ee_plot"][:,:,0j]

# %%
results[list(results)[0]]["MET_lt_150_dilep_os_ee_plot"].integrate("qual_sum")

# %%
for mp, mp_dict in results[list(results)[1]].items():
    print()
    print(mp)
    print()
    for key, item in mp_dict.items():
        if "_count" in key:
            print(key)
            print(item)

# %%
result['dilep_m_ll_gt_1p0_MET_lt_150_plot'].plot()

# %%
result['dilep_diag_cut_a2_MET_lt_150_plot'].plot()

# %%
result['dilep_dr_gt_0p1_MET_lt_150_plot'].plot()

# %%
results[results.keys()]['dilep_diag_cut_2_MET_lt_150_plot'].plot()

# %%
results[list(results.keys())[0]]['dilep_diag_cut_2_MET_lt_150_count']

# %%
results[list(results.keys())[0]]['dilep_diag_cut_2_MET_lt_150_plot'].plot()

# %%
results[list(results.keys())[1]]['dilep_m_ll_gt_1p0_300_290_MET_lt_150_plot'].plot()

# %%
results[list(results.keys())[1]]

# %%
for key in results[list(results.keys())[1]].keys():
    print(key)
