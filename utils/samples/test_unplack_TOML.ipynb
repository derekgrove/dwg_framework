# %% [markdown]
# # starting at 27:30 in [Jim's video](https://youtu.be/FoxNS6nlbD0?si=JncVX0ye53LivX4_&t=1650)

# %%
from pathlib import Path
p = Path('.')

for subdir in p.iterdir():
    if subdir.is_dir():
        print(subdir)
p
# Out:
# __pycache__
# .ipynb_checkpoints
# PosixPath('.')

# %%
toml_path = "fileset.toml"

# %%
import unpack_TOML

# %%
unpack_TOML._format_fileset(toml_path, "JetMET2022C", -1, "cern")
# Out:
# {'JetMET2022C': {'files': ['root://cms-xrd-global.cern.ch//store/data/Run2022C/JetMET/NANOAOD/22Sep2023-v1/2530000/0b6815d2-5fd6-4b55-9374-a32b052c129b.root',
#    'root://cms-xrd-global.cern.ch//store/data/Run2022C/JetMET/NANOAOD/22Sep2023-v1/2530000/27f35e3e-ceb0-4707-98fd-65e35243d747.root',
#    'root://cms-xrd-global.cern.ch//store/data/Run2022C/JetMET/NANOAOD/22Sep2023-v1/2530000/e4bb6e09-af8e-4b2a-8f9e-5a3b72de50ab.root'],
#   'treename': 'Events',
#   'metadata': {'is_MC': False, 'is_UL': False, 'is_SMS': False}}}
